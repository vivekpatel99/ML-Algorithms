# %% [markdown]
# <a href="https://colab.research.google.com/github/vivekpatel99/ML-Algorithms/blob/main/Gradient_Descent_For_Neural_Network_from_scrach.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Implement Gradient Descent For Neural Network (or Logistic Regression)

# %% [markdown]
# This dataset contains details of 1000 customers who intend to buy a car, considering their annual salaries. \
#
# Columns:
# * User ID
# * Gender
# * Age
# * Annual Salary
# * Purchase Decision (No = 0; Yes = 1) (PREDICT)

# %% [markdown]
# It is a binary logistic regression problem as there are only two possible outcomes (i.e. Yes/No).

# %%
# !pip install opendatasets --upgrade --quiet

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import pandas as pd
from matplotlib import pyplot as plt
import pandas as pd
import os
import pandas as pd
import opendatasets as od

# %%
dataset_url = 'https://www.kaggle.com/datasets/gabrielsantello/cars-purchase-decision-dataset?datasetId=2329085&sortBy=voteCount'
data_dir = './cars-purchase-decision-dataset'
if not os.path.isdir(data_dir):
    od.download(dataset_url)

# %%
car_data_csv = os.path.join(data_dir, 'car_data.csv')
car_purchase_df = pd.read_csv(car_data_csv)
car_purchase_df.head()
# Out:
#    User ID Gender  Age  AnnualSalary  Purchased
# 0      385   Male   35         20000          0
# 1      681   Male   40         43500          0
# 2      353   Male   49         74000          0
# 3      895   Male   40        107500          1
# 4      661   Male   25         79000          0

# %% [markdown]
# Check for missing values

# %%
car_purchase_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   User ID       1000 non-null   int64
#  1   Gender        1000 non-null   object
#  2   Age           1000 non-null   int64
#  3   AnnualSalary  1000 non-null   int64
#  4   Purchased     1000 non-null   int64
# dtypes: int64(4), object(1)
# memory usage: 39.2+ KB

# %% [markdown]
# ## Gradient Decent

# %% [markdown]
# Equation for calculating weights \
# $$w_n = w_n - learning rate * \frac{\partial }{\partial w_n}$$
#
# Where $$ \frac{\partial }{\partial w_n}  = \frac{1}{n}\sum_{i=1}^{n}x_i (\hat y_i - y_i)$$
# Equation for calculating bias \
# $$b = b - learning rate * \frac{\partial }{\partial b}$$

# %% [markdown]
# ## Separate dataset into train and test

# %%
from sklearn.model_selection import train_test_split

# %%
X =  car_purchase_df.drop(['User ID', 'Purchased'], axis=1)
X.head()
# Out:
#   Gender  Age  AnnualSalary
# 0   Male   35         20000
# 1   Male   40         43500
# 2   Male   49         74000
# 3   Male   40        107500
# 4   Male   25         79000

# %%
X.Gender = X.Gender.map({'Male':1, 'Female': 0})

# %%
y = car_purchase_df.Purchased
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      1
# 4      0
#       ..
# 995    0
# 996    0
# 997    1
# 998    1
# 999    0
# Name: Purchased, Length: 1000, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=X.Gender)

# %% [markdown]
# ## Preprocessing Convert Categorical columns to numerical and scale the data

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ## Using keras

# %%
model = keras.Sequential([
    keras.layers.Dense(1, input_shape=(3,), activation='sigmoid', kernel_initializer='ones', bias_initializer='zeros')
])

# %%
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.fit(X_train_scaled, y_train, epochs=500)
# Out:
# Epoch 1/500
# 24/24 [==============================] - 1s 2ms/step - loss: 0.5245 - accuracy: 0.7000
# Epoch 2/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5165 - accuracy: 0.7107
# Epoch 3/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5087 - accuracy: 0.7160
# Epoch 4/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5014 - accuracy: 0.7213
# Epoch 5/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4944 - accuracy: 0.7307
# Epoch 6/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.4878 - accuracy: 0.7360
# Epoch 7/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4815 - accuracy: 0.7360
# Epoch 8/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4755 - accuracy: 0.7467
# Epoch 9/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.4698 - accuracy: 0.7507
# Epoch 10/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4644 - accuracy: 0.7587
# Epoch 11/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4591 - accuracy: 0.7627
# Epoch 12/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4541 - accuracy: 0.7613
# Epoch 13/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4494 - accuracy: 0.7640
# Epoch 14/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.4449 - accuracy: 0.7707
# Epoch 15/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4408 - accuracy: 0.7760
# Epoch 16/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4370 - accuracy: 0.7800
# Epoch 17/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4332 - accuracy: 0.7840
# Epoch 18/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4297 - accuracy: 0.7853
# Epoch 19/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4264 - accuracy: 0.7893
# Epoch 20/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4232 - accuracy: 0.7880
# Epoch 21/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4202 - accuracy: 0.7907
# Epoch 22/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.4173 - accuracy: 0.7973
# Epoch 23/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.4147 - accuracy: 0.7960
# Epoch 24/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.4121 - accuracy: 0.7987
# Epoch 25/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.4097 - accuracy: 0.8000
# Epoch 26/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4075 - accuracy: 0.8040
# Epoch 27/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4053 - accuracy: 0.8053
# Epoch 28/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4032 - accuracy: 0.8080
# Epoch 29/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4013 - accuracy: 0.8080
# Epoch 30/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3995 - accuracy: 0.8147
# Epoch 31/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3977 - accuracy: 0.8147
# Epoch 32/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3962 - accuracy: 0.8133
# Epoch 33/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3946 - accuracy: 0.8147
# Epoch 34/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3931 - accuracy: 0.8107
# Epoch 35/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3918 - accuracy: 0.8147
# Epoch 36/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3904 - accuracy: 0.8173
# Epoch 37/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3892 - accuracy: 0.8173
# Epoch 38/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3880 - accuracy: 0.8173
# Epoch 39/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3868 - accuracy: 0.8160
# Epoch 40/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3857 - accuracy: 0.8160
# Epoch 41/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3848 - accuracy: 0.8160
# Epoch 42/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3837 - accuracy: 0.8160
# Epoch 43/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3828 - accuracy: 0.8147
# Epoch 44/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3821 - accuracy: 0.8147
# Epoch 45/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3812 - accuracy: 0.8173
# Epoch 46/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3805 - accuracy: 0.8267
# Epoch 47/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3797 - accuracy: 0.8267
# Epoch 48/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3790 - accuracy: 0.8253
# Epoch 49/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3784 - accuracy: 0.8253
# Epoch 50/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3778 - accuracy: 0.8240
# Epoch 51/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3771 - accuracy: 0.8253
# Epoch 52/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3766 - accuracy: 0.8253
# Epoch 53/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3760 - accuracy: 0.8267
# Epoch 54/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3755 - accuracy: 0.8267
# Epoch 55/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3750 - accuracy: 0.8267
# Epoch 56/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3745 - accuracy: 0.8253
# Epoch 57/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3741 - accuracy: 0.8240
# Epoch 58/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3737 - accuracy: 0.8240
# Epoch 59/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3733 - accuracy: 0.8280
# Epoch 60/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3729 - accuracy: 0.8293
# Epoch 61/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3725 - accuracy: 0.8293
# Epoch 62/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3722 - accuracy: 0.8307
# Epoch 63/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3718 - accuracy: 0.8307
# Epoch 64/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3715 - accuracy: 0.8333
# Epoch 65/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3712 - accuracy: 0.8333
# Epoch 66/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3709 - accuracy: 0.8360
# Epoch 67/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3706 - accuracy: 0.8347
# Epoch 68/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3703 - accuracy: 0.8347
# Epoch 69/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.3701 - accuracy: 0.8347
# Epoch 70/500
# 24/24 [==============================] - 0s 7ms/step - loss: 0.3699 - accuracy: 0.8347
# Epoch 71/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3696 - accuracy: 0.8333
# Epoch 72/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3694 - accuracy: 0.8347
# Epoch 73/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3692 - accuracy: 0.8347
# Epoch 74/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3691 - accuracy: 0.8347
# Epoch 75/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3688 - accuracy: 0.8347
# Epoch 76/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3686 - accuracy: 0.8333
# Epoch 77/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3684 - accuracy: 0.8360
# Epoch 78/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3682 - accuracy: 0.8360
# Epoch 79/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3680 - accuracy: 0.8360
# Epoch 80/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3678 - accuracy: 0.8360
# Epoch 81/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3677 - accuracy: 0.8373
# Epoch 82/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3676 - accuracy: 0.8387
# Epoch 83/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3674 - accuracy: 0.8373
# Epoch 84/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3672 - accuracy: 0.8387
# Epoch 85/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.3671 - accuracy: 0.8387
# Epoch 86/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3670 - accuracy: 0.8387
# Epoch 87/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3668 - accuracy: 0.8387
# Epoch 88/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3667 - accuracy: 0.8387
# Epoch 89/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.3666 - accuracy: 0.8387
# Epoch 90/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3665 - accuracy: 0.8387
# Epoch 91/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3663 - accuracy: 0.8387
# Epoch 92/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3662 - accuracy: 0.8387
# Epoch 93/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3661 - accuracy: 0.8387
# Epoch 94/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3660 - accuracy: 0.8373
# Epoch 95/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3659 - accuracy: 0.8373
# Epoch 96/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3658 - accuracy: 0.8373
# Epoch 97/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3657 - accuracy: 0.8373
# Epoch 98/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3657 - accuracy: 0.8373
# Epoch 99/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3656 - accuracy: 0.8373
# Epoch 100/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.3655 - accuracy: 0.8373
# Epoch 101/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.3654 - accuracy: 0.8373
# Epoch 102/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3654 - accuracy: 0.8373
# Epoch 103/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3652 - accuracy: 0.8373
# Epoch 104/500
# 24/24 [==============================] - 0s 7ms/step - loss: 0.3652 - accuracy: 0.8373
# Epoch 105/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3651 - accuracy: 0.8373
# Epoch 106/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3650 - accuracy: 0.8373
# Epoch 107/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3650 - accuracy: 0.8373
# Epoch 108/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3649 - accuracy: 0.8373
# Epoch 109/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3648 - accuracy: 0.8373
# Epoch 110/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3647 - accuracy: 0.8373
# Epoch 111/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3647 - accuracy: 0.8373
# Epoch 112/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3647 - accuracy: 0.8373
# Epoch 113/500
# 24/24 [==============================] - 0s 7ms/step - loss: 0.3646 - accuracy: 0.8373
# Epoch 114/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3646 - accuracy: 0.8387
# Epoch 115/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3645 - accuracy: 0.8373
# Epoch 116/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3644 - accuracy: 0.8387
# Epoch 117/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3644 - accuracy: 0.8387
# Epoch 118/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3643 - accuracy: 0.8387
# Epoch 119/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.3643 - accuracy: 0.8387
# Epoch 120/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3642 - accuracy: 0.8387
# Epoch 121/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3642 - accuracy: 0.8387
# Epoch 122/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.3641 - accuracy: 0.8387
# Epoch 123/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3641 - accuracy: 0.8387
# Epoch 124/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3640 - accuracy: 0.8387
# Epoch 125/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.3640 - accuracy: 0.8387
# Epoch 126/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3640 - accuracy: 0.8387
# Epoch 127/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3639 - accuracy: 0.8387
# Epoch 128/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.3639 - accuracy: 0.8387
# Epoch 129/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.3638 - accuracy: 0.8387
# Epoch 130/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3638 - accuracy: 0.8387
# Epoch 131/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3638 - accuracy: 0.8387
# Epoch 132/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3638 - accuracy: 0.8387
# Epoch 133/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3637 - accuracy: 0.8387
# Epoch 134/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.3637 - accuracy: 0.8387
# Epoch 135/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.3636 - accuracy: 0.8387
# Epoch 136/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.3636 - accuracy: 0.8387
# Epoch 137/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3636 - accuracy: 0.8387
# Epoch 138/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3635 - accuracy: 0.8373
# Epoch 139/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.3635 - accuracy: 0.8387
# Epoch 140/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.3635 - accuracy: 0.8387
# Epoch 141/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3635 - accuracy: 0.8387
# Epoch 142/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3635 - accuracy: 0.8387
# Epoch 143/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3634 - accuracy: 0.8373
# Epoch 144/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.3634 - accuracy: 0.8387
# Epoch 145/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.3634 - accuracy: 0.8400
# Epoch 146/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3633 - accuracy: 0.8400
# Epoch 147/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3634 - accuracy: 0.8387
# Epoch 148/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3633 - accuracy: 0.8400
# Epoch 149/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.3633 - accuracy: 0.8400
# Epoch 150/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3633 - accuracy: 0.8413
# Epoch 151/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.3633 - accuracy: 0.8400
# Epoch 152/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3633 - accuracy: 0.8413
# Epoch 153/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3632 - accuracy: 0.8400
# Epoch 154/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3633 - accuracy: 0.8400
# Epoch 155/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.3632 - accuracy: 0.8413
# Epoch 156/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3632 - accuracy: 0.8413
# Epoch 157/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3632 - accuracy: 0.8400
# Epoch 158/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3631 - accuracy: 0.8400
# Epoch 159/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3631 - accuracy: 0.8400
# Epoch 160/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3631 - accuracy: 0.8400
# Epoch 161/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3631 - accuracy: 0.8400
# Epoch 162/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.3631 - accuracy: 0.8400
# Epoch 163/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3631 - accuracy: 0.8413
# Epoch 164/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3630 - accuracy: 0.8413
# Epoch 165/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.3631 - accuracy: 0.8400
# Epoch 166/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3631 - accuracy: 0.8413
# Epoch 167/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3630 - accuracy: 0.8413
# Epoch 168/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3630 - accuracy: 0.8413
# Epoch 169/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.3630 - accuracy: 0.8413
# Epoch 170/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.3630 - accuracy: 0.8400
# Epoch 171/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3630 - accuracy: 0.8400
# Epoch 172/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3630 - accuracy: 0.8413
# Epoch 173/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.3629 - accuracy: 0.8413
# Epoch 174/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3630 - accuracy: 0.8400
# Epoch 175/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3629 - accuracy: 0.8400
# Epoch 176/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3629 - accuracy: 0.8400
# Epoch 177/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3630 - accuracy: 0.8400
# Epoch 178/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.3630 - accuracy: 0.8400
# Epoch 179/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3630 - accuracy: 0.8413
# Epoch 180/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3629 - accuracy: 0.8400
# Epoch 181/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3629 - accuracy: 0.8413
# Epoch 182/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3629 - accuracy: 0.8400
# Epoch 183/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.3629 - accuracy: 0.8400
# Epoch 184/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3629 - accuracy: 0.8413
# Epoch 185/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3629 - accuracy: 0.8387
# Epoch 186/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.3628 - accuracy: 0.8400
# Epoch 187/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3628 - accuracy: 0.8400
# Epoch 188/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.3628 - accuracy: 0.8400
# Epoch 189/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.3628 - accuracy: 0.8400
# Epoch 190/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.3629 - accuracy: 0.8400
# Epoch 191/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.3628 - accuracy: 0.8387
# Epoch 192/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3628 - accuracy: 0.8387
# Epoch 193/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.3628 - accuracy: 0.8387
# Epoch 194/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.3628 - accuracy: 0.8400
# Epoch 195/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.3628 - accuracy: 0.8400
# Epoch 196/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3628 - accuracy: 0.8400
# Epoch 197/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3628 - accuracy: 0.8400
# Epoch 198/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3628 - accuracy: 0.8400
# Epoch 199/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3627 - accuracy: 0.8400
# Epoch 200/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3628 - accuracy: 0.8400
# Epoch 201/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3628 - accuracy: 0.8400
# Epoch 202/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.3627 - accuracy: 0.8400
# Epoch 203/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3628 - accuracy: 0.8400
# Epoch 204/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3628 - accuracy: 0.8400
# Epoch 205/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3627 - accuracy: 0.8400
# Epoch 206/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3627 - accuracy: 0.8400
# Epoch 207/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.3627 - accuracy: 0.8400
# Epoch 208/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3627 - accuracy: 0.8400
# Epoch 209/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3627 - accuracy: 0.8400
# Epoch 210/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3627 - accuracy: 0.8400
# Epoch 211/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3627 - accuracy: 0.8400
# Epoch 212/500
# 24/24 [==============================] - 0s 7ms/step - loss: 0.3627 - accuracy: 0.8400
# Epoch 213/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.3627 - accuracy: 0.8400
# Epoch 214/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.3627 - accuracy: 0.8400
# Epoch 215/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.3627 - accuracy: 0.8400
# Epoch 216/500
# 24/24 [==============================] - 0s 10ms/step - loss: 0.3627 - accuracy: 0.8400
# Epoch 217/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.3627 - accuracy: 0.8400
# Epoch 218/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.3627 - accuracy: 0.8400
# Epoch 219/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.3627 - accuracy: 0.8400
# Epoch 220/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.3627 - accuracy: 0.8400
# Epoch 221/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3627 - accuracy: 0.8400
# Epoch 222/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.3627 - accuracy: 0.8400
# Epoch 223/500
# 24/24 [==============================] - 0s 7ms/step - loss: 0.3627 - accuracy: 0.8400
# Epoch 224/500
# 24/24 [==============================] - 0s 7ms/step - loss: 0.3627 - accuracy: 0.8400
# Epoch 225/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3627 - accuracy: 0.8400
# Epoch 226/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3627 - accuracy: 0.8400
# Epoch 227/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3627 - accuracy: 0.8400
# Epoch 228/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3628 - accuracy: 0.8400
# Epoch 229/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3627 - accuracy: 0.8400
# Epoch 230/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 231/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3627 - accuracy: 0.8400
# Epoch 232/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3627 - accuracy: 0.8400
# Epoch 233/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 234/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 235/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3627 - accuracy: 0.8400
# Epoch 236/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 237/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 238/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 239/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3627 - accuracy: 0.8400
# Epoch 240/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 241/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 242/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3627 - accuracy: 0.8400
# Epoch 243/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 244/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 245/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 246/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 247/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 248/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 249/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 250/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 251/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 252/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 253/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 254/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 255/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 256/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 257/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 258/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 259/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 260/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 261/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 262/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 263/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 264/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 265/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 266/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 267/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 268/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 269/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 270/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 271/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 272/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 273/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 274/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 275/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 276/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 277/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 278/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 279/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 280/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 281/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 282/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 283/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 284/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 285/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 286/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 287/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 288/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 289/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 290/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 291/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 292/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 293/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 294/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 295/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 296/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 297/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 298/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 299/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 300/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 301/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 302/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 303/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 304/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 305/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 306/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 307/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 308/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 309/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 310/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 311/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 312/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 313/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 314/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 315/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 316/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3625 - accuracy: 0.8387
# Epoch 317/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 318/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 319/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3625 - accuracy: 0.8387
# Epoch 320/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 321/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 322/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3625 - accuracy: 0.8387
# Epoch 323/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 324/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 325/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 326/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 327/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 328/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 329/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 330/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 331/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 332/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3625 - accuracy: 0.8387
# Epoch 333/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 334/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 335/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 336/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 337/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3625 - accuracy: 0.8387
# Epoch 338/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 339/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 340/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3625 - accuracy: 0.8387
# Epoch 341/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 342/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 343/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 344/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 345/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 346/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 347/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 348/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 349/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 350/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 351/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 352/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 353/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3625 - accuracy: 0.8387
# Epoch 354/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 355/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 356/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3625 - accuracy: 0.8400
# Epoch 357/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 358/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 359/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3625 - accuracy: 0.8387
# Epoch 360/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 361/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 362/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 363/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3625 - accuracy: 0.8387
# Epoch 364/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 365/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 366/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 367/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 368/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 369/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 370/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 371/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 372/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 373/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 374/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 375/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 376/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 377/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 378/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 379/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 380/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 381/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 382/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 383/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 384/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 385/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 386/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3625 - accuracy: 0.8400
# Epoch 387/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 388/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3625 - accuracy: 0.8400
# Epoch 389/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3625 - accuracy: 0.8400
# Epoch 390/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 391/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 392/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3625 - accuracy: 0.8400
# Epoch 393/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 394/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 395/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3625 - accuracy: 0.8387
# Epoch 396/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 397/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3625 - accuracy: 0.8400
# Epoch 398/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 399/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 400/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 401/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 402/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8413
# Epoch 403/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3625 - accuracy: 0.8387
# Epoch 404/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 405/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3625 - accuracy: 0.8400
# Epoch 406/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 407/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 408/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 409/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 410/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 411/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3626 - accuracy: 0.8413
# Epoch 412/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3625 - accuracy: 0.8413
# Epoch 413/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3625 - accuracy: 0.8413
# Epoch 414/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 415/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 416/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 417/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3625 - accuracy: 0.8387
# Epoch 418/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 419/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 420/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 421/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 422/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 423/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 424/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3625 - accuracy: 0.8387
# Epoch 425/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8413
# Epoch 426/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 427/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 428/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 429/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 430/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 431/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 432/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 433/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8413
# Epoch 434/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 435/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 436/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 437/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3625 - accuracy: 0.8400
# Epoch 438/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 439/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 440/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 441/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3625 - accuracy: 0.8400
# Epoch 442/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 443/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3625 - accuracy: 0.8400
# Epoch 444/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 445/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 446/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 447/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 448/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 449/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3625 - accuracy: 0.8387
# Epoch 450/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 451/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 452/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3625 - accuracy: 0.8387
# Epoch 453/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3625 - accuracy: 0.8387
# Epoch 454/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 455/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3625 - accuracy: 0.8387
# Epoch 456/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3625 - accuracy: 0.8387
# Epoch 457/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3625 - accuracy: 0.8387
# Epoch 458/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3625 - accuracy: 0.8387
# Epoch 459/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 460/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 461/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3625 - accuracy: 0.8387
# Epoch 462/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 463/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 464/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 465/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3625 - accuracy: 0.8400
# Epoch 466/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3625 - accuracy: 0.8400
# Epoch 467/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 468/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 469/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 470/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 471/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 472/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3625 - accuracy: 0.8387
# Epoch 473/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3625 - accuracy: 0.8400
# Epoch 474/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3625 - accuracy: 0.8387
# Epoch 475/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 476/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 477/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 478/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 479/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 480/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 481/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 482/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 483/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 484/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 485/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 486/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3625 - accuracy: 0.8387
# Epoch 487/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 488/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 489/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 490/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3625 - accuracy: 0.8387
# Epoch 491/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3625 - accuracy: 0.8387
# Epoch 492/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 493/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 494/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 495/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 496/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 497/500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3626 - accuracy: 0.8400
# Epoch 498/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 499/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387
# Epoch 500/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8387

# %%
model.evaluate(X_test_scaled, y_test)
# Out:
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4039 - accuracy: 0.8280
# [0.40394359827041626, 0.828000009059906]

# %% [markdown]
# Get the value of weights and bias from the model

# %%
coef, intercept = model.get_weights()
coef, intercept
# Out:
# (array([[0.23373315],
#         [2.5493822 ],
#         [1.2048651 ]], dtype=float32), array([-0.66569364], dtype=float32))

# %% [markdown]
# ## Lets write our own Gradient Descent now

# %%
def sigmoid(x):
    return 1/(1 + np.exp(-x))

# %% [markdown]
# Let's write our own prediction function

# %%
def prediction_function(gender, age, annual_salary):
    weighted_sum = coef[0]*gender + coef[1]*age + coef[2]*annual_salary + intercept
    return sigmoid(weighted_sum)

# %% [markdown]
# Let's define loss function to calculate losses during Gradient discent
#
# $$ log \ loss \ or \ binary \ cross\ entropy = - \frac{1}{n}\sum_{i=0}^{n}y_i log(\hat y_i) +(1 - y_i). log(1-\hat y_i) $$

# %%
def log_loss(y_true, y_predicted):
    epsilon = 1e-15
    y_predicted_new = [max(i,epsilon) for i in y_predicted]
    y_predicted_new = [min(i,1-epsilon) for i in y_predicted_new]
    y_predicted_new = np.array(y_predicted_new)
    return -np.mean(y_true*np.log(y_predicted_new)+(1-y_true)*np.log(1-y_predicted_new))

# %% [markdown]
# Define Gradient descent

# %% [markdown]
# Here we are going to use only 3 features (Gender, Age, AnnualSalary), UserId is not useful.
# So our Equtions are looking like following, \
# for Gender
# $$w_0 = w_0 - learning \ rate * \frac{\partial }{\partial w_0}$$
#
# Where,  \
# $$ \frac{\partial }{\partial w_0}  = \frac{1}{n}\sum_{i=1}^{n}x_i (\hat y_i - y_i)$$

# %% [markdown]
# for Age
# $$w_1 = w_1 - learning \ rate * \frac{\partial }{\partial w_1}$$
#
# Where,  \
# $$ \frac{\partial }{\partial w_1}  = \frac{1}{n}\sum_{i=1}^{n}x_i (\hat y_i - y_i)$$

# %% [markdown]
# for AnnualSalary
# $$w_2 = w_2 - learning \ rate * \frac{\partial }{\partial w_2}$$
#
# Where,  \
# $$ \frac{\partial }{\partial w_2}  = \frac{1}{n}\sum_{i=1}^{n}x_i (\hat y_i - y_i)$$

# %% [markdown]
# for Bias, it is the same equation as before,
# $$b = b - learning \ rate * \frac{\partial }{\partial b}$$
#
# Where,  \
# $$ \frac{\partial }{\partial b}  = \frac{1}{n}\sum_{i=1}^{n} (\hat y_i - y_i)$$

# %%
def gradient_descent(gender, age, annual_salary, y_true,  epochs, loss_thresold):
    # initialize weights and bias
    w0 = w1 = w2 = 1
    bias = 0
    learning_rate= 0.5
    n = len(gender)
    for i in range(epochs):

        # find first random weights
        weighted_sum = w0*gender + w1*age + w2*annual_salary + bias
        y_pred = sigmoid(weighted_sum)
        loss = log_loss(y_true, y_pred)
        
        # Calculate partial derivatives 
        w0d = 1/n * (gender.T @ (y_pred - y_true))
        w1d = 1/n * (age.T @ (y_pred - y_true))
        w2d = 1/n * (annual_salary.T @ (y_pred - y_true))

        bias_d  = np.mean(y_pred - y_true)

        # Create a final formula for each weight
        w0 = w0 - learning_rate * w0d
        w1 = w1 - learning_rate * w1d
        w2 = w2 - learning_rate * w2d

        bias = bias - learning_rate * bias_d 
        
        print (f'Epoch:{i}, w0:{w0}, w1:{w1}, w2:{w2}, bias:{bias}, loss:{loss}')
        if loss<=loss_thresold:
            break
    return w0, w1, w2, bias

# %% [markdown]
# Convert back to pandas dataframe from numpy array

# %%
gradient_descent(X_train_scaled[:, 0], # all rows, 0th column
                 X_train_scaled[:, 1], # all rows, 0th column
                 X_train_scaled[:, 2], # all rows, 0th column
                 y_train,
                 1000,
                 0.3626)
# Out:
# Epoch:0, w0:0.9161867405605904, w1:1.071890755288459, w2:0.9952660208681701, bias:-0.04025501819616826, loss:0.5280521057753129
# Epoch:1, w0:0.8411830674311904, w1:1.1368132944421787, w2:0.9897514458182458, bias:-0.07703539719304175, loss:0.5017595012111972
# Epoch:2, w0:0.7740178925118222, w1:1.1957128162644375, w2:0.9839223802053491, bias:-0.11067121308821626, loss:0.4804085252341044
# Epoch:3, w0:0.7138180865503557, w1:1.2494005668408645, w2:0.9781010411558307, bias:-0.14147587623126287, loss:0.4629904365627866
# Epoch:4, w0:0.6598069740956147, w1:1.2985658725283915, w2:0.9725047730792751, bias:-0.16973683526869002, loss:0.4487097143439152
# Epoch:5, w0:0.6112978666722705, w1:1.3437917609727807, w2:0.9672752211331614, bias:-0.1957128070684041, loss:0.4369405227206958
# Epoch:6, w0:0.5676854943067733, w1:1.3855708417059693, w2:0.9624997700203514, bias:-0.2196343604548869, loss:0.42719021777745836
# Epoch:7, w0:0.5284369598733688, w1:1.4243198590133632, w2:0.9582271803210524, bias:-0.2417060229688729, loss:0.4190700389943386
# Epoch:8, w0:0.4930830527940502, w1:1.4603923368188332, w2:0.9544789596434236, bias:-0.2621089290872022, loss:0.41227211321674173
# Epoch:9, w0:0.46121029942503566, w1:1.4940892508085066, w2:0.951257622673329, bias:-0.2810035198167995, loss:0.40655162253126337
# Epoch:10, w0:0.4324538774120149, w1:1.52566789327767, w2:0.948552685668758, bias:-0.29853207093073436, loss:0.40171304268554814
# Epoch:11, w0:0.4064913938516036, w1:1.5553491763727987, w2:0.9463450095588692, bias:-0.31482096528613135, loss:0.39759952951082694
# Epoch:12, w0:0.3830374677344319, w1:1.583323627410163, w2:0.9446099372051808, bias:-0.3299826923021276, loss:0.3940847182425661
# Epoch:13, w0:0.36183903398978373, w1:1.6097563072134344, w2:0.9433195487284143, bias:-0.34411758834822026, loss:0.3910663667386408
# Epoch:14, w0:0.34267128170270617, w1:1.6347908495514893, w2:0.9424442711087909, bias:-0.3573153438078254, loss:0.38846140842651283
# Epoch:15, w0:0.3253341431076385, w1:1.6585527863031666, w2:0.9419540148667054, bias:-0.36965630558525686, loss:0.3862020857016378
# Epoch:16, w0:0.3096492577153824, w1:1.6811522928331308, w2:0.9418189646005171, bias:-0.3812126027536305, loss:0.3842329143795876
# Epoch:17, w0:0.2954573448205158, w1:1.7026864624304034, w2:0.9420101165959603, bias:-0.3920491203489265, loss:0.38250829003417736
# Epoch:18, w0:0.28261592640529853, w1:1.723241197522287, w2:0.9424996321561344, bias:-0.402224343174464, loss:0.3809905923050377
# Epoch:19, w0:0.27099735053890084, w1:1.7428927882356458, w2:0.9432610572620639, bias:-0.4117910884187434, loss:0.37964867725971907
# Epoch:20, w0:0.2604870725591568, w1:1.7617092351053942, w2:0.9442694458920241, bias:-0.4207971431198369, loss:0.37845667350187007
# Epoch:21, w0:0.25098215758726633, w1:1.7797513617147402, w2:0.9455014145273994, bias:-0.42928582009294425, loss:0.3773930170679239
# Epoch:22, w0:0.24238997331654982, w1:1.7970737542562552, w2:0.9469351481286405, bias:-0.4372964438687171, loss:0.3764396748383193
# Epoch:23, w0:0.23462704662162648, w1:1.8137255579789995, w2:0.9485503725028082, bias:-0.4448647764357798, loss:0.3755815173804701
# Epoch:24, w0:0.2276180614510124, w1:1.8297511548706815, w2:0.9503283040111562, bias:-0.45202339110078954, loss:0.37480581070865004
# Epoch:25, w0:0.22129497878845275, w1:1.845190742423967, w2:0.9522515846193921, bias:-0.45880200153303324, loss:0.3741018030351494
# Epoch:26, w0:0.21559626228273357, w1:1.8600808297216145, w2:0.9543042081084234, bias:-0.4652277520114264, loss:0.3734603876769142
# Epoch:27, w0:0.21046619552880896, w1:1.8744546641636968, w2:0.9564714416432222, bias:-0.4713254740081211, loss:0.3728738272305766
# Epoch:28, w0:0.2058542790012531, w1:1.8883425998079784, w2:0.9587397456967961, bias:-0.4771179134978029, loss:0.3723355272050015
# Epoch:29, w0:0.2017146963512292, w1:1.9017724163882133, w2:0.9610966944377067, bias:-0.4826259327525147, loss:0.37183984970674383
# Epoch:30, w0:0.1980058412287298, w1:1.9147695965252818, w2:0.9635308980334109, bias:-0.4878686898495798, loss:0.37138195966341275
# Epoch:31, w0:0.1946898970236778, w1:1.9273575673819954, w2:0.966031927838691, bias:-0.492863798669167, loss:0.37095769755945873
# Epoch:32, w0:0.19173246296702406, w1:1.9395579119780864, w2:0.9685902450845039, bias:-0.49762747177512906, loss:0.3705634738373388
# Epoch:33, w0:0.18910222092518347, w1:1.9513905545328893, w2:0.9711971334248539, bias:-0.5021746482470585, loss:0.37019618105266183
# Epoch:34, w0:0.18677063798231439, w1:1.9628739235041164, w2:0.9738446355132552, bias:-0.5065191082539422, loss:0.3698531206173232
# Epoch:35, w0:0.1847117005554466, w1:1.9740250954136547, w2:0.976525493647662, bias:-0.510673575922792, loss:0.3695319415604594
# Epoch:36, w0:0.18290167634440008, w1:1.9848599220728405, w2:0.9792330944296997, bias:-0.5146498118528482, loss:0.3692305892148258
# Epoch:37, w0:0.1813189008961531, w1:1.995393143421994, w2:0.9819614173203564, bias:-0.5184586964521162, loss:0.36894726212050033
# Epoch:38, w0:0.17994358597386245, w1:2.005638487867514, w2:0.9847049869322996, bias:-0.5221103051236641, loss:0.36868037574784285
# Epoch:39, w0:0.17875764727422774, w1:2.0156087617226706, w2:0.9874588288729175, bias:-0.525613976200578, loss:0.3684285318924881
# Epoch:40, w0:0.17774454934184516, w1:2.0253159291258354, w2:0.9902184289377115, bias:-0.5289783724176159, loss:0.36819049279865584
# Epoch:41, w0:0.17688916579278335, w1:2.034771183614465, w2:0.9929796954475811, bias:-0.5322115366117971, loss:0.367965159232631
# Epoch:42, w0:0.17617765318788448, w1:2.0439850123683265, w2:0.9957389245234136, bias:-0.5353209422612085, loss:0.3677515518632981
# Epoch:43, w0:0.17559733709435893, w1:2.0529672539960906, w2:0.9984927680954286, bias:-0.5383135393993258, loss:0.36754879541703767
# Epoch:44, w0:0.17513660904642211, w1:2.061727150621222, w2:1.0012382044515935, bias:-0.5411957963795684, loss:0.3673561051647917
# Epoch:45, w0:0.17478483326568237, w1:2.070273394922602, w2:1.0039725111381272, bias:-0.5439737379102926, loss:0.3671727753734702
# Epoch:46, w0:0.1745322621328374, w1:2.0786141726996425, w2:1.0066932400349273, bias:-0.5466529797328497, loss:0.3669981694150971
# Epoch:47, w0:0.17436995951661755, w1:2.0867572014584157, w2:1.0093981944391468, bias:-0.5492387602737223, loss:0.36683171127763065
# Epoch:48, w0:0.17428973116607746, w1:2.094709765452566, w2:1.0120854080007444, bias:-0.551735969565301, loss:0.3666728782631826
# Epoch:49, w0:0.1742840614602069, w1:2.102478747558852, w2:1.0147531253643491, bias:-0.5541491756978586, loss:0.36652119469399624
# Epoch:50, w0:0.174346055886046, w1:2.11007065832072, w2:1.0173997843820408, bias:-0.5564826490371374, loss:0.3663762264753037
# Epoch:51, w0:0.17446938868445794, w1:2.1174916624532374, w2:1.0200239997715155, bias:-0.5587403844171709, loss:0.3662375763881103
# Epoch:52, w0:0.17464825516263807, w1:2.124747603067984, w2:1.0226245481035061, bias:-0.5609261214960748, loss:0.3661048800048996
# Epoch:53, w0:0.17487732822535954, w1:2.1318440238464316, w2:1.025200354011209, bias:-0.5630433634431969, loss:0.36597780213791264
# Epoch:54, w0:0.17515171872376367, w1:2.1387861893641436, w2:1.0277504775228106, bias:-0.5650953941088761, loss:0.36585603374358255
# Epoch:55, w0:0.17546693926196893, w1:2.145579103745343, w2:1.030274102426004, bias:-0.567085293812861, loss:0.3657392892183937
# Epoch:56, w0:0.1758188711385577, w1:2.1522275278074554, w2:1.0327705255806436, bias:-0.5690159538739293, loss:0.36562730403122595
# Epoch:57, w0:0.17620373413268425, w1:2.1587359948378175, w2:1.0352391471024207, bias:-0.5708900899912265, loss:0.36551983264549553
# Epoch:58, w0:0.1766180588736246, w1:2.165108825129442, w2:1.0376794613466829, bias:-0.5727102545771251, loss:0.3654166466913433
# Epoch:59, w0:0.17705866155849717, w1:2.1713501393892845, w2:1.0400910486272756, bias:-0.5744788481318414, loss:0.36531753335397327
# Epoch:60, w0:0.1775226208059936, w1:2.1774638711206267, w2:1.0424735676105983, bias:-0.5761981297414882, loss:0.36522229394919636
# Epoch:61, w0:0.17800725645460605, w1:2.183453778070743, w2:1.044826748329962, bias:-0.5778702267735905, loss:0.36513074266141626
# Epoch:62, w0:0.17851011013230117, w1:2.189323452825775, w2:1.0471503857698348, bias:-0.5794971438372171, loss:0.3650427054228424
# Epoch:63, w0:0.17902892744112686, w1:2.1950763326265585, w2:1.0494443339736985, bias:-0.5810807710687252, loss:0.364958018915725
# Epoch:64, w0:0.1795616416150629, w1:2.2007157084718885, w2:1.0517085006330416, bias:-0.5826228917985669, loss:0.3648765296819633
# Epoch:65, w0:0.1801063585227319, w1:2.2062447335692448, w2:1.053942842118501, bias:-0.5841251896496213, loss:0.36479809332661944
# Epoch:66, w0:0.18066134289854469, w1:2.211666431187256, w2:1.0561473589173676, bias:-0.5855892551130235, loss:0.36472257380371853
# Epoch:67, w0:0.18122500569660896, w1:2.216983701959042, w2:1.0583220914446028, bias:-0.5870165916433993, loss:0.3646498427743092
# Epoch:68, w0:0.18179589247141564, w1:2.2221993306809997, w2:1.0604671161972143, bias:-0.588408621311758, loss:0.36457977902810257
# Epoch:69, w0:0.18237267269804694, w1:2.2273159926474824, w2:1.0625825422243005, bias:-0.5897666900509774, loss:0.3645122679611727
# Epoch:70, w0:0.18295412995252738, w1:2.2323362595581506, w2:1.0646685078873401, bias:-0.5910920725258167, loss:0.3644472011031913
# Epoch:71, w0:0.1835391528800525, w1:2.23726260503147, w2:1.0667251778873827, bias:-0.5923859766566762, loss:0.364384475688525
# Epoch:72, w0:0.1841267268852607, w1:2.242097409754857, w2:1.0687527405376915, bias:-0.5936495478238534, loss:0.3643239942662509
# Epoch:73, w0:0.18471592648453156, w1:2.246842966299297, w2:1.070751405262142, bias:-0.594883872776809, loss:0.3642656643447834
# Epoch:74, w0:0.18530590826556248, w1:2.251501483623862, w2:1.0727214003012757, bias:-0.5960899832709186, loss:0.36420939806734176
# Epoch:75, w0:0.18589590440425025, w1:2.256075091293354, w2:1.074662970609375, bias:-0.5972688594523328, loss:0.3641551119149636
# Epoch:76, w0:0.18648521669323476, w1:2.260565843430355, w2:1.0765763759272755, bias:-0.5984214330098856, loss:0.36410272643416935
# Epoch:77, w0:0.18707321104039334, w1:2.2649757224211693, w2:1.0784618890168587, bias:-0.599548590111451, loss:0.36405216598673873
# Epoch:78, w0:0.1876593123991453, w1:2.2693066423935266, w2:1.080319794044309, bias:-0.6006511741407458, loss:0.3640033585193596
# Epoch:79, w0:0.18824300009567219, w1:2.2735604524824593, w2:1.0821503851002505, bias:-0.6017299882492989, loss:0.3639562353511798
# Epoch:80, w0:0.18882380352111333, w1:2.277738939899427, w2:1.0839539648458374, bias:-0.6027857977371367, loss:0.3639107309775157
# Epoch:81, w0:0.18940129815948384, w1:2.281843832818554, w2:1.0857308432747452, bias:-0.6038193322746642, loss:0.3638667828881776
# Epoch:82, w0:0.18997510192451156, w1:2.28587680309274, w2:1.087481336581814, bias:-0.6048312879772454, loss:0.3638243313990411
# Epoch:83, w0:0.19054487178082236, w1:2.289839468811401, w2:1.0892057661298324, bias:-0.6058223293430893, loss:0.36378331949565
# Epoch:84, w0:0.1911103006269381, w1:2.2937333967106843, w2:1.0909044575066311, bias:-0.6067930910642286, loss:0.3637436926877693
# Epoch:85, w0:0.191671114419411, w1:2.297560104446154, w2:1.0925777396652718, bias:-0.6077441797196244, loss:0.3637053988739187
# Epoch:86, w0:0.19222706951911422, w1:2.301321062737189, w2:1.0942259441406996, bias:-0.6086761753587402, loss:0.36366838821502906
# Epoch:87, w0:0.19277795024225916, w1:2.3050176973916243, w2:1.09584940433674, bias:-0.6095896329832972, loss:0.36363261301644434
# Epoch:88, w0:0.1933235666001273, w1:2.308651391218539, w2:1.0974484548778176, bias:-0.6104850839343355, loss:0.363598027617578
# Epoch:89, w0:0.19386375221280097, w1:2.312223485836489, w2:1.09902343102021, bias:-0.6113630371911778, loss:0.3635645882885994
# Epoch:90, w0:0.19439836238336333, w1:2.3157352833839564, w2:1.1005746681180606, bias:-0.6122239805883927, loss:0.3635322531335902
# Epoch:91, w0:0.1949272723201249, w1:2.319188048138285, w2:1.1021025011397538, bias:-0.6130683819564088, loss:0.36350098199966224
# Epoch:92, w0:0.1954503754954282, w1:2.322583008048925, w2:1.1036072642305985, bias:-0.6138966901910086, loss:0.3634707363915796
# Epoch:93, w0:0.19596758213049456, w1:2.3259213561903755, w2:1.1050892903180844, bias:-0.6147093362565496, loss:0.3634414793914707
# Epoch:94, w0:0.1964788177966128, w1:2.329204252139846, w2:1.1065489107562714, bias:-0.6155067341274068, loss:0.36341317558325237
# Epoch:95, w0:0.19698402212373722, w1:2.332432823284291, w2:1.1079864550061382, bias:-0.6162892816718021, loss:0.3633857909814245
# Epoch:96, w0:0.19748314760826488, w1:2.3356081660611494, w2:1.1094022503489702, bias:-0.6170573614818871, loss:0.36335929296392394
# Epoch:97, w0:0.19797615851240982, w1:2.3387313471368225, w2:1.1107966216300886, bias:-0.6178113416536662, loss:0.3633336502087509
# Epoch:98, w0:0.19846302984818387, w1:2.3418034045266345, w2:1.1121698910304394, bias:-0.6185515765200927, loss:0.3633088326341114
# Epoch:99, w0:0.19894374643953985, w1:2.3448253486597754, w2:1.113522377863753, bias:-0.6192784073404297, loss:0.36328481134183405
# Epoch:100, w0:0.19941830205673378, w1:2.347798163392483, w2:1.1148543983971633, bias:-0.6199921629487526, loss:0.36326155856384584
# Epoch:101, w0:0.19988669861742317, w1:2.3507228069724975, w2:1.1161662656933393, bias:-0.6206931603642645, loss:0.36323904761150533
# Epoch:102, w0:0.20034894544944298, w1:2.353600212957625, w2:1.11745828947234, bias:-0.6213817053659094, loss:0.36321725282760736
# Epoch:103, w0:0.20080505861058986, w1:2.356431291091057, w2:1.1187307759915337, bias:-0.6220580930335948, loss:0.3631961495408933
# Epoch:104, w0:0.20125506026110496, w1:2.359216928135911, w2:1.1199840279420623, bias:-0.6227226082581743, loss:0.36317571402290527
# Epoch:105, w0:0.2016989780848755, w1:2.361957988671309, w2:1.1212183443604427, bias:-0.6233755262221916, loss:0.36315592344704417
# Epoch:106, w0:0.20213684475567995, w1:2.364655315852149, w2:1.1224340205540102, bias:-0.6240171128532515, loss:0.36313675584969346
# Epoch:107, w0:0.2025686974450817, w1:2.36730973213459, w2:1.1236313480390137, bias:-0.6246476252517524, loss:0.3631181900932878
# Epoch:108, w0:0.20299457736883492, w1:2.369922039969145, w2:1.124810614490256, bias:-0.6252673120946004, loss:0.3631002058312101
# Epoch:109, w0:0.20341452936890367, w1:2.3724930224631495, w2:1.1259721037012727, bias:-0.6258764140164108, loss:0.36308278347440953
# Epoch:110, w0:0.20382860152841623, w1:2.375023444014266, w2:1.1271160955541086, bias:-0.6264751639696056, loss:0.3630659041596417
# Epoch:111, w0:0.20423684481707755, w1:2.377514050916583, w2:1.1282428659978363, bias:-0.6270637875647161, loss:0.36304954971923903
# Epoch:112, w0:0.2046393127647509, w1:2.3799655719407644, w2:1.1293526870350192, bias:-0.6276425033921166, loss:0.3630337026523243
# Epoch:113, w0:0.2050360611610915, w1:2.382378718889621, w2:1.1304458267153923, bias:-0.6282115233263287, loss:0.36301834609738687
# Epoch:114, w0:0.2054271477792742, w1:2.3847541871303877, w2:1.131522549136085, bias:-0.6287710528139652, loss:0.36300346380614645
# Epoch:115, w0:0.20581263212200443, w1:2.3870926561049175, w2:1.132583114447769, bias:-0.6293212911463065, loss:0.3629890401186357
# Epoch:116, w0:0.20619257518813686, w1:2.389394789818923, w2:1.1336277788661595, bias:-0.6298624317174425, loss:0.36297505993943285
# Epoch:117, w0:0.20656703925835204, w1:2.391661237311336, w2:1.1346567946883452, bias:-0.6303946622688458, loss:0.3629615087149862
# Epoch:118, w0:0.2069360876984568, w1:2.3938926331047874, w2:1.135670410313465, bias:-0.6309181651211921, loss:0.3629483724119705
# Epoch:119, w0:0.207299784778981, w1:2.3960895976381518, w2:1.136668870267286, bias:-0.6314331173941855, loss:0.36293563749662144
# Epoch:120, w0:0.20765819550984232, w1:2.3982527376820464, w2:1.1376524152302767, bias:-0.6319396912150992, loss:0.3629232909149991
# Epoch:121, w0:0.2080113854889424, w1:2.400382646738123, w2:1.1386212820687978, bias:-0.6324380539166973, loss:0.3629113200741302
# Epoch:122, w0:0.20835942076364142, w1:2.4024799054229415, w2:1.139575703869067, bias:-0.6329283682251593, loss:0.36289971282398603
# Epoch:123, w0:0.2087023677041371, w1:2.4045450818371688, w2:1.1405159099735824, bias:-0.63341079243859, loss:0.3628884574402535
# Epoch:124, w0:0.20904029288784617, w1:2.4065787319208067, w2:1.1414421260197096, bias:-0.6338854805966594, loss:0.3628775426078581
# Epoch:125, w0:0.2093732629939525, w1:2.408581399795111, w2:1.142354573980172, bias:-0.6343525826418849, loss:0.362866957405204
# Epoch:126, w0:0.2097013447073495, w1:2.4105536180918263, w2:1.1432534722051941, bias:-0.6348122445730331, loss:0.3628566912890942
# Epoch:127, w0:0.21002460463125963, w1:2.4124959082703277, w2:1.144139035466078, bias:-0.6352646085910909, loss:0.36284673408029644
# Epoch:128, w0:0.21034310920786892, w1:2.4144087809232295, w2:1.145011475000005, bias:-0.6357098132382257, loss:0.36283707594972636
# Epoch:129, w0:0.21065692464636146, w1:2.4162927360709854, w2:1.1458709985558762, bias:-0.63614799353013, loss:0.3628277074052154
# Epoch:130, w0:0.21096611685778593, w1:2.4181482634459828, w2:1.1467178104410194, bias:-0.6365792810821194, loss:0.3628186192788376
# Epoch:131, w0:0.21127075139622686, w1:2.419975842766599, w2:1.147552111568607, bias:-0.637003804229333, loss:0.3628098027147663
# Epoch:132, w0:0.21157089340579335, w1:2.421775944001674, w2:1.1483740995056402, bias:-0.6374216881413601, loss:0.3628012491576387
# Epoch:133, w0:0.2118666075729732, w1:2.4235490276258123, w2:1.1491839685213694, bias:-0.6378330549316006, loss:0.3627929503414009
# Epoch:134, w0:0.21215795808393434, w1:2.425295544865925, w2:1.1499819096360326, bias:-0.6382380237616458, loss:0.3627848982786151
# Epoch:135, w0:0.21244500858638582, w1:2.427015937939387, w2:1.1507681106698022, bias:-0.6386367109409512, loss:0.36277708525020397
# Epoch:136, w0:0.21272782215564, w1:2.42871064028417, w2:1.1515427562918445, bias:-0.6390292300220518, loss:0.36276950379561396
# Epoch:137, w0:0.21300646126454337, w1:2.430380076781294, w2:1.1523060280693995, bias:-0.6394156918915628, loss:0.3627621467033781
# Epoch:138, w0:0.21328098775696844, w1:2.4320246639699237, w2:1.1530581045168038, bias:-0.6397962048571857, loss:0.3627550070020599
# Epoch:139, w0:0.21355146282458196, w1:2.433644810255411, w2:1.1537991611443803, bias:-0.6401708747309347, loss:0.36274807795156117
# Epoch:140, w0:0.2138179469866255, w1:2.435240916110587, w2:1.154529370507132, bias:-0.6405398049087785, loss:0.36274135303477806
# Epoch:141, w0:0.21408050007246454, w1:2.4368133742705687, w2:1.1552489022531782, bias:-0.640903096446887, loss:0.36273482594958817
# Epoch:142, w0:0.21433918120667958, w1:2.438362569921357, w2:1.1559579231718815, bias:-0.6412608481346572, loss:0.3627284906011564
# Epoch:143, w0:0.21459404879649058, w1:2.4398888808824664, w2:1.1566565972416178, bias:-0.6416131565646843, loss:0.3627223410945428
# Epoch:144, w0:0.21484516052132055, w1:2.441392677783833, w2:1.1573450856771454, bias:-0.6419601161998347, loss:0.36271637172760196
# Epoch:145, w0:0.21509257332431964, w1:2.442874324237224, w2:1.1580235469765379, bias:-0.6423018194375671, loss:0.3627105769841585
# Epoch:146, w0:0.2153363434056834, w1:2.444334177002366, w2:1.1586921369676448, bias:-0.6426383566716406, loss:0.36270495152744886
# Epoch:147, w0:0.21557652621761234, w1:2.4457725861480024, w2:1.159351008854053, bias:-0.6429698163513402, loss:0.36269949019381675
# Epoch:148, w0:0.21581317646077047, w1:2.4471898952080657, w2:1.1600003132605206, bias:-0.6432962850383444, loss:0.36269418798665104
# Epoch:149, w0:0.21604634808211196, w1:2.4485864413331657, w2:1.1606401982778625, bias:-0.6436178474613483, loss:0.36268904007055774
# Epoch:150, w0:0.21627609427395436, w1:2.4499625554375615, w2:1.1612708095072688, bias:-0.6439345865685552, loss:0.3626840417657526
# Epoch:151, w0:0.21650246747418658, w1:2.451318562341792, w2:1.1618922901040363, bias:-0.6442465835781376, loss:0.3626791885426695
# Epoch:152, w0:0.21672551936750753, w1:2.452654780911126, w2:1.1625047808207027, bias:-0.6445539180267674, loss:0.36267447601677094
# Epoch:153, w0:0.2169453008876001, w1:2.4539715241899898, w2:1.16310842004957, bias:-0.6448566678163065, loss:0.3626698999435558
# Epoch:154, w0:0.217161862220152, w1:2.455269099532516, w2:1.1637033438646072, bias:-0.6451549092587447, loss:0.3626654562137542
# Epoch:155, w0:0.21737525280664127, w1:2.456547808729357, w2:1.1642896860627252, bias:-0.6454487171194705, loss:0.3626611408487018
# Epoch:156, w0:0.21758552134881218, w1:2.4578079481308994, w2:1.1648675782044198, bias:-0.6457381646589477, loss:0.36265694999588793
# Epoch:157, w0:0.21779271581377072, w1:2.4590498087670083, w2:1.1654371496537745, bias:-0.6460233236728766, loss:0.3626528799246671
# Epoch:158, w0:0.21799688343963639, w1:2.4602736764634225, w2:1.1659985276178253, bias:-0.6463042645309065, loss:0.3626489270221305
# Epoch:159, w0:0.21819807074169092, w1:2.4614798319549207, w2:1.1665518371852817, bias:-0.6465810562139669, loss:0.3626450877891293
# Epoch:160, w0:0.21839632351896926, w1:2.462668550995374, w2:1.1670972013646075, bias:-0.6468537663502797, loss:0.362641358836444
# Epoch:161, w0:0.21859168686124275, w1:2.4638401044647886, w2:1.16763474112146, bias:-0.6471224612501115, loss:0.36263773688109313
# Epoch:162, w0:0.21878420515634842, w1:2.4649947584734435, w2:1.1681645754154897, bias:-0.6473872059393223, loss:0.3626342187427772
# Epoch:163, w0:0.21897392209782143, w1:2.4661327744632273, w2:1.1686868212365047, bias:-0.6476480641917637, loss:0.362630801340452
# Epoch:164, w0:0.21916088069279216, w1:2.467254409306261, w2:1.1692015936400026, bias:-0.6479050985605771, loss:0.36262748168902453
# Epoch:165, w0:0.2193451232701113, w1:2.468359915400905, w2:1.169709005782074, bias:-0.6481583704084399, loss:0.3626242568961692
# Epoch:166, w0:0.21952669148867068, w1:2.4694495407652353, w2:1.1702091689536829, bias:-0.6484079399368048, loss:0.3626211241592573
# Epoch:167, w0:0.21970562634588892, w1:2.470523529128072, w2:1.17070219261433, bias:-0.6486538662141749, loss:0.36261808076239804
# Epoch:168, w0:0.2198819681863344, w1:2.4715821200176404, w2:1.171188184425105, bias:-0.6488962072034563, loss:0.36261512407358304
# Epoch:169, w0:0.22005575671046024, w1:2.4726255488479443, w2:1.171667250281134, bias:-0.6491350197884268, loss:0.36261225154193305
# Epoch:170, w0:0.22022703098342772, w1:2.4736540470029245, w2:1.1721394943434285, bias:-0.6493703597993566, loss:0.3626094606950428
# Epoch:171, w0:0.22039582944399705, w1:2.474667841918472, w2:1.1726050190701442, bias:-0.6496022820378176, loss:0.3626067491364191
# Epoch:172, w0:0.22056218991346588, w1:2.4756671571623663, w2:1.173063925247259, bias:-0.6498308403007124, loss:0.3626041145430081
# Epoch:173, w0:0.22072614960463813, w1:2.476652212512205, w2:1.1735163120186725, bias:-0.6500560874035576, loss:0.3626015546628113
# Epoch:174, w0:0.22088774513080653, w1:2.4776232240313854, w2:1.1739622769157416, bias:-0.6502780752030489, loss:0.3625990673125825
# (0.22088774513080653,
#  2.4776232240313854,
#  1.1739622769157416,
#  -0.6502780752030489)

# %%
coef, intercept
# Out:
# (array([[0.23373315],
#         [2.5493822 ],
#         [1.2048651 ]], dtype=float32), array([-0.66569364], dtype=float32))

# %% [markdown]
# As you can notice coef and intercept are really close to each other

# %% [markdown]
# Little clean up for Gradient Descent functionn
# * we do not need to calculate all the weights separately. numpy can handle it for us. so updated code will look like this

# %%
def gradient_descent(X, y_true,  epochs, loss_thresold):
    num_features = X.shape[1] # num of columns/features
    # initialize weights and bias
    weights = np.ones(shape=num_features)
    bias = 0
    learning_rate= 0.5
    n = X.shape[0] # num of rows
    for i in range(epochs):

        # find first random weights
        weighted_sum = (weights @ X.T) + bias
        y_pred = sigmoid(weighted_sum)
        loss = log_loss(y_true, y_pred)
        
        # Calculate partial derivatives 
        weight_deriv = 1/n * (X.T @ (y_pred - y_true))

        bias_d  = np.mean(y_pred - y_true)

        # Create a final formula for each weight
        weights = weights - learning_rate * weight_deriv

        bias = bias - learning_rate * bias_d 
        if i%50==0: #  print only at 50th interation
            print (f'Epoch:{i}, weights:{weights},  bias:{bias}, loss:{loss}')
            
        if loss<=loss_thresold:
            print (f'Epoch:{i}, weights:{weights},  bias:{bias}, loss:{loss}')
            break
    return weights, bias

# %%
gradient_descent(X_train_scaled,
                 y_train,
                 1000,
                 0.3626)
# Out:
# Epoch:0, weights:[0.91618674 1.07189076 0.99526602],  bias:-0.04025501819616826, loss:0.5280521057753129
# Epoch:50, weights:[0.17434606 2.11007066 1.01739978],  bias:-0.5564826490371374, loss:0.3663762264753037
# Epoch:100, weights:[0.1994183  2.34779816 1.1148544 ],  bias:-0.6199921629487526, loss:0.36326155856384584
# Epoch:150, weights:[0.21627609 2.44996256 1.16127081],  bias:-0.6439345865685552, loss:0.3626840417657526
# Epoch:174, weights:[0.22088775 2.47762322 1.17396228],  bias:-0.6502780752030489, loss:0.3625990673125825
# (array([0.22088775, 2.47762322, 1.17396228]), -0.6502780752030489)
